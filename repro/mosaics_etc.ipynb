# %% [markdown]
# # Mosaics etc.
#
# In this notebook I run through the calculations for some of the claims about mosaic rhymes, and explore some of the features for rhyme searching and rhyme display.

# %%
from bs4 import BeautifulSoup

import importlib

from mqdq import rhyme, utils, rhyme_classes, babble
from mqdq import line_analyzer as la

import random
import operator
import bisect
import string
import copy
import re
import scipy as sp
import pandas as pd
import glob
import umap
import os
import subprocess

# %%
allbabs = []

tris_bab = babble.Babbler.from_file(*sorted(glob.glob('mqdq/OV-tri*.xml')), name = 'Tristia')
allbabs.append(tris_bab)

tib_babs = babble.multibabs(sorted(glob.glob('mqdq/TIB-ele*.xml')),"Tibullus")
allbabs.extend(tib_babs)

tib_single_bab = babble.Babbler.from_file(*sorted(glob.glob('mqdq/TIB-ele*.xml')),name ="Tibullus")
allbabs.append(tib_single_bab)

cat_soup, cat_ll = utils.slurp('mqdq/CATVLL-carm.xml')
cat64_bab = babble.Babbler(utils.clean(cat_soup('division')[63]('line')), name = "Cat64")
allbabs.append(cat64_bab)

aen_babs = babble.bookbabs('mqdq/VERG-aene.xml', 'Aeneid')
allbabs.extend(aen_babs)

aen_single_bab = babble.Babbler.from_file('mqdq/VERG-aene.xml', name='Aeneid')
allbabs.append(aen_single_bab)

geo_babs = babble.bookbabs('mqdq/VERG-geor.xml', 'Georgics')
allbabs.extend(geo_babs)

geo_single_bab = babble.Babbler.from_file('mqdq/VERG-geor.xml', name='Georgics')
allbabs.append(geo_single_bab)

sat_babs = babble.bookbabs('mqdq/IVV-satu.xml', 'Juv. Sat.')
allbabs.extend(sat_babs)

sat_single_bab = babble.Babbler.from_file('mqdq/IVV-satu.xml', name='Juv. Sat.')
allbabs.append(sat_single_bab)

met_babs = babble.bookbabs('mqdq/OV-meta.xml', 'Metamorphoses')
allbabs.extend(met_babs)

met_single_bab = babble.Babbler.from_file('mqdq/OV-meta.xml', name='Metamorphoses')
allbabs.append(met_single_bab)

puni_babs = babble.bookbabs('mqdq/SIL-puni.xml', 'Punica')
allbabs.extend(puni_babs)

puni_single_bab = babble.Babbler.from_file('mqdq/SIL-puni.xml', name='Punica')
allbabs.append(puni_single_bab)

theb_babs = babble.bookbabs('mqdq/STAT-theb.xml', 'Thebaid')
allbabs.extend(theb_babs)

theb_single_bab = babble.Babbler.from_file('mqdq/STAT-theb.xml', name='Thebaid')
allbabs.append(theb_single_bab)

phars_babs = babble.bookbabs('mqdq/LVCAN-phar.xml', 'Pharsalia')
allbabs.extend(phars_babs)

phars_single_bab = babble.Babbler.from_file('mqdq/LVCAN-phar.xml', name='Pharsalia')
allbabs.append(phars_single_bab)

prop_babs = babble.multibabs(sorted(glob.glob('mqdq/PROP-ele*.xml')),"Propertius")
allbabs.extend(prop_babs)

prop_single_bab = babble.Babbler.from_file(*sorted(glob.glob('mqdq/PROP-ele*.xml')),name ="Propertius")
allbabs.append(prop_single_bab)

ep_bab = babble.Babbler.from_file('mqdq/OV-epis.xml', name="Heroides")
allbabs.append(ep_bab)

aram_bab = babble.Babbler.from_file('mqdq/OV-aram.xml', name="Ars")
allbabs.append(aram_bab)

fast_bab = babble.Babbler.from_file('mqdq/OV-fast.xml', name="Fasti")
allbabs.append(fast_bab)

arg_babs = babble.bookbabs('mqdq/VAL_FL-argo.xml', 'Argonautica')
allbabs.extend(arg_babs)

arg_single_bab = babble.Babbler.from_file('mqdq/VAL_FL-argo.xml', name='Argonautica')
allbabs.append(arg_single_bab)

rena_babs = babble.bookbabs('mqdq/LVCR-rena.xml', 'DRN')
allbabs.extend(rena_babs)

rena_single_bab = babble.Babbler.from_file('mqdq/LVCR-rena.xml', name='DRN')
allbabs.append(rena_single_bab)

apot_bab = babble.Babbler.from_file('mqdq/PRVD-apot.xml', name='Apotheosis')
allbabs.append(apot_bab)

hamart_bab = babble.Babbler.from_file('mqdq/PRVD-hama.xml', name='Hamartigenia')
allbabs.append(hamart_bab)

psych_bab = babble.Babbler.from_file('mqdq/PRVD-psyc.xml', name='Psychomachia')
allbabs.append(psych_bab)

horsat_babs = babble.multibabs(sorted(glob.glob('mqdq/HOR-sat*.xml')),"Hor. Sat.")
allbabs.extend(horsat_babs)

horsat_single_bab = babble.Babbler.from_file(*sorted(glob.glob('mqdq/HOR-sat*.xml')),name ="Hor. Sat.")
allbabs.append(horsat_single_bab)

# %% [markdown]
# ## Custom Mosaic search function
#
# Note that this does not include a score for line initial rhymes! Those statistics were introduced after the mosaic analysis had been performed. This is something that should probably be added in future (it is a fairly minor change to the code) but the aim of this notebook is to cover the work as it was done to support the preprint.

# %%
NEUTRAL = {
    "ult_count": 1.0,
    "ult_score": 1.0,
    "penult_count": 1.0,
    "penult_score": 1.0,
    "ante_count": 1.0,
    "ante_score": 1.0,
    "mid_count": 1.0,
    "mid_score": 1.0,
    "score_bias": 0.5,
    "score_exponent": 2.5,
}

def locate_mosaics(bab, thresh=5.5):
    
    '''
    Find all the four-line mosaics with a score above a certain threshold
    in a supplied Babbler (representing one text)
    '''
    
    # sll is already syllabified (creates a preprocessed LineSet)
    sll = bab._syl_source()

    res = []
    for idx in range(0,len(sll)-4):
        ll = copy.copy(sll[idx:idx+4])
        # These methods link (assign rhymes) and color the words in the LineSet
        ll.colorlink()
        s = ll.score(config=NEUTRAL)
        if s >= thresh:
            res.append((ll,s))
    # sort by score, descending
    res.sort(key=lambda x: x[1], reverse=True)
    return res

# %%
# This is the general approach, which yields "Mosaics per thousand lines"

met_res = locate_mosaics(met_single_bab, thresh=5.5)
len(met_res)/len(met_single_bab.raw_source)*1000
# Out:
# 34.14106087101341

# %%
# The results from the Met reflect Ovid's love of repeats with minor variation

for q, s in met_res[:10]:
    utils.nbshow(q, book=True)
    print('\n' + '-'*15 + "^ Score: %.2f ^" % s + '-'*15 + '\n')
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:353 </span>
#       <span>Multi</span>
#       <span>illum</span>
#       <span style="
#     background-color: #c5d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">iuuenes,</span>
#       <span>multae</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">cupiere</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">puellae;</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:354 </span>
#       <span>Sed</span>
#       <span>(fuit</span>
#       <span>in</span>
#       <span>tenera</span>
#       <span>tam</span>
#       <span>dura</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">superbia</span>
#       <span>forma)</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:355 </span>
#       <span>Nulli</span>
#       <span>illum</span>
#       <span style="
#     background-color: #c5d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">iuuenes,</span>
#       <span>nullae</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">tetigere</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">puellae.</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:356 </span>
#       <span>Adspicit</span>
#       <span>hunc</span>
#       <span style="
#     background-color: #79abd2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">trepidos</span>
#       <span>agitantem</span>
#       <span>in</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">retia</span>
#       <span style="
#     background-color: #79abd2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">ceruos</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 9.30 ^---------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">15:614 </span>
#       <span>Inuiti</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">uidere</span>
#       <span>caput</span>
#       <span>nec</span>
#       <span style="
#     background-color: #d2cc79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">honore</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">carere</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">15:615 </span>
#       <span>Vlterius</span>
#       <span style="
#     background-color: #d29279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">passi</span>
#       <span>festam</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">inposuere</span>
#       <span>coronam;</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">15:616 </span>
#       <span>At</span>
#       <span>proceres,</span>
#       <span>quoniam</span>
#       <span>muros</span>
#       <span style="
#     background-color: #d2cc79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">intrare</span>
#       <span>uetaris,</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">15:617 </span>
#       <span>Ruris</span>
#       <span style="
#     background-color: #d29279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">honorati</span>
#       <span>tantum</span>
#       <span>tibi,</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">Cipe,</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">dedere,</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 8.63 ^---------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">12:217 </span>
#       <span>Praesignis</span>
#       <span>facie.</span>
#       <span>Felicem</span>
#       <span style="
#     background-color: #79d2bf;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">diximus</span>
#       <span style="
#     background-color: #b1d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">illa</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">12:218 </span>
#       <span>Coniuge</span>
#       <span>Pirithoum,</span>
#       <span>quod</span>
#       <span>paene</span>
#       <span style="
#     background-color: #79d2bf;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">fefellimus</span>
#       <span>omen.</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">12:219 </span>
#       <span>Nam</span>
#       <span>tibi</span>
#       <span style="
#     background-color: #79bed2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">saeuorum</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">saeuissime</span>
#       <span style="
#     background-color: #79bed2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">Centaurorum,</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">12:220 </span>
#       <span>Euryte,</span>
#       <span>quam</span>
#       <span>uino</span>
#       <span>pectus</span>
#       <span>tam</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">uirgine</span>
#       <span style="
#     background-color: #b1d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">uisa</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 8.42 ^---------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">12:219 </span>
#       <span>Nam</span>
#       <span>tibi</span>
#       <span style="
#     background-color: #79bed2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">saeuorum</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">saeuissime</span>
#       <span style="
#     background-color: #79bed2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">Centaurorum,</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">12:220 </span>
#       <span>Euryte,</span>
#       <span>quam</span>
#       <span>uino</span>
#       <span>pectus</span>
#       <span>tam</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">uirgine</span>
#       <span>uisa</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">12:221 </span>
#       <span>Ardet</span>
#       <span>et</span>
#       <span>ebrietas</span>
#       <span>geminata</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">libidine</span>
#       <span>regnat.</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">12:222 </span>
#       <span>Protinus</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">euersae</span>
#       <span>turbant</span>
#       <span>conuiuia</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">mensae</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 8.41 ^---------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:306 </span>
#       <span>&quot;Salmaci,</span>
#       <span>uel</span>
#       <span>iaculum,</span>
#       <span>uel</span>
#       <span>pictas</span>
#       <span>sume</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">pharetras</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:307 </span>
#       <span>Et</span>
#       <span>tua</span>
#       <span>cum</span>
#       <span style="
#     background-color: #d2a579;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">duris</span>
#       <span>uenatibus</span>
#       <span style="
#     background-color: #81d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">otia</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">misce.&quot;</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:308 </span>
#       <span>Nec</span>
#       <span>iaculum</span>
#       <span style="
#     background-color: #d2a579;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">sumit</span>
#       <span>nec</span>
#       <span>pictas</span>
#       <span>illa</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">pharetras</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:309 </span>
#       <span>Nec</span>
#       <span>sua</span>
#       <span>cum</span>
#       <span style="
#     background-color: #d2a579;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">duris</span>
#       <span>uenatibus</span>
#       <span style="
#     background-color: #81d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">otia</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">miscet;</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 8.33 ^---------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 1:481 </span>
#       <span>Saepe</span>
#       <span>pater</span>
#       <span style="
#     background-color: #d27e79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">dixit</span>
#       <span>&quot;generum</span>
#       <span>mihi,</span>
#       <span>filia,</span>
#       <span style="
#     background-color: #d2cc79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">debes,&quot;</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 1:482 </span>
#       <span>Saepe</span>
#       <span>pater</span>
#       <span style="
#     background-color: #d27e79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">dixit</span>
#       <span>&quot;debes</span>
#       <span>mihi,</span>
#       <span style="
#     background-color: #81d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">nata,</span>
#       <span style="
#     background-color: #bbd279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">nepotes:&quot;</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 1:483 </span>
#       <span>Illa</span>
#       <span>uelut</span>
#       <span>crimen</span>
#       <span>taedas</span>
#       <span style="
#     background-color: #81d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">exosa</span>
#       <span style="
#     background-color: #d2cc79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">iugales</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 1:484 </span>
#       <span>Pulchra</span>
#       <span>uerecundo</span>
#       <span>subfuderat</span>
#       <span style="
#     background-color: #81d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">ora</span>
#       <span style="
#     background-color: #bbd279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">rubore</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 8.33 ^---------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">14:128 </span>
#       <span>Templa</span>
#       <span>tibi</span>
#       <span>statuam,</span>
#       <span>tribuam</span>
#       <span>tibi</span>
#       <span style="
#     background-color: #d2a579;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">turis</span>
#       <span style="
#     background-color: #bbd279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">honores.</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">14:129 </span>
#       <span>Respicit</span>
#       <span>hunc</span>
#       <span style="
#     background-color: #d2cc79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">uates</span>
#       <span>et</span>
#       <span style="
#     background-color: #79d2bf;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">suspiratibus</span>
#       <span>haustis:</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">14:130 </span>
#       <span>&quot;Nec</span>
#       <span>dea</span>
#       <span>sum&quot;,</span>
#       <span>dixit</span>
#       <span>&quot;nec</span>
#       <span>sacri</span>
#       <span style="
#     background-color: #d2a579;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">turis</span>
#       <span style="
#     background-color: #bbd279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">honore</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">14:131 </span>
#       <span>Humanum</span>
#       <span style="
#     background-color: #d2cc79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">dignare</span>
#       <span>caput;</span>
#       <span>neu</span>
#       <span style="
#     background-color: #79d2bf;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">nescius</span>
#       <span style="
#     background-color: #d2cc79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">erres,</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 8.20 ^---------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 7:14  </span>
#       <span>Nam</span>
#       <span>cur</span>
#       <span>iussa</span>
#       <span style="
#     background-color: #d27e79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">patris</span>
#       <span>nimium</span>
#       <span>mihi</span>
#       <span style="
#     background-color: #8ad279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">dura</span>
#       <span>uidentur?</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 7:15  </span>
#       <span>Sunt</span>
#       <span>quoque</span>
#       <span>dura</span>
#       <span style="
#     background-color: #d27e79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">nimis!</span>
#       <span>cur,</span>
#       <span>quem</span>
#       <span>modo</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">denique</span>
#       <span style="
#     background-color: #d27e79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">uidi,</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 7:16  </span>
#       <span>Ne</span>
#       <span>pereat,</span>
#       <span style="
#     background-color: #79b5d2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">timeo?</span>
#       <span>quae</span>
#       <span>tanti</span>
#       <span style="
#     background-color: #8ad279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">causa</span>
#       <span>timoris?</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 7:17  </span>
#       <span>Excute</span>
#       <span style="
#     background-color: #79b5d2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">uirgineo</span>
#       <span>conceptas</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">pectore</span>
#       <span>flammas,</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 8.17 ^---------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 2:809 </span>
#       <span>Felicisque</span>
#       <span style="
#     background-color: #d2af79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">bonis</span>
#       <span>non</span>
#       <span>lenius</span>
#       <span style="
#     background-color: #79c8d2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">uritur</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">Herses</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 2:810 </span>
#       <span>Quam</span>
#       <span>cum</span>
#       <span style="
#     background-color: #d2af79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">spinosis</span>
#       <span>ignis</span>
#       <span style="
#     background-color: #79c8d2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">supponitur</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">herbis,</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 2:811 </span>
#       <span>Quae</span>
#       <span>neque</span>
#       <span>dant</span>
#       <span>flammas</span>
#       <span>lenique</span>
#       <span style="
#     background-color: #bbd279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">tepore</span>
#       <span>cremantur.</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 2:812 </span>
#       <span>Saepe</span>
#       <span>mori</span>
#       <span style="
#     background-color: #d2af79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">uoluit,</span>
#       <span>ne</span>
#       <span>quicquam</span>
#       <span style="
#     background-color: #bbd279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">tale</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">uideret,</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 8.16 ^---------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">14:54  </span>
#       <span>Sol</span>
#       <span>erat</span>
#       <span>et</span>
#       <span style="
#     background-color: #b1d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">minimas</span>
#       <span>a</span>
#       <span>uertice</span>
#       <span>fecerat</span>
#       <span>umbras.</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">14:55  </span>
#       <span>Hunc</span>
#       <span>dea</span>
#       <span style="
#     background-color: #b1d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">praeuitiat</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">portentificisque</span>
#       <span style="
#     background-color: #d28879;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">uenenis</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">14:56  </span>
#       <span>Inquinat;</span>
#       <span>hic</span>
#       <span>pressos</span>
#       <span>latices</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">radice</span>
#       <span style="
#     background-color: #d28879;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">nocenti</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em">14:57  </span>
#       <span>Spargit</span>
#       <span>et</span>
#       <span style="
#     background-color: #79c8d2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">obscurum</span>
#       <span>uerborum</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">ambage</span>
#       <span style="
#     background-color: #79c8d2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">nouorum</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 8.14 ^---------------

# %% [markdown]
# ## Another custom search function - Golden Lions
#
# This is really just as an example of the flexibility of the scan/search pattern.

# %%
STRIP_STRESS = str.maketrans({'`':None})
def shiny_leo(ll):
    
    '''
    Implement the search function pattern required by the Babbler class.
    
    In this case, search for 'golden lions' which is a pattern I made up,
    consisting of a leonine rhyme which also encloses an alliteration.
    '''
    
    if len(ll) != 1:
        raise ValueError("Need %s line." % 1)

    l = copy.copy(ll[0])
    w1 = l.fetch("mid")
    w2 = l.fetch(-1)
    s = rhyme.word_rhyme(w1, w2)
    if not s >= 1.75:
        return None
    # once word_rhyme is above the threshold both words have syls
    try:
        f1 =l[-2].syls[0].translate(STRIP_STRESS).lower()[0]
        f2 = l[-3].syls[0].translate(STRIP_STRESS).lower()[0]
    except:
        print(l)
    if not( f1==f2 and l[-4]==w1 ):
        return None

    w1.color = w2.get_color()
    w2.color = w1.color
    w1.lock_color, w2.lock_color = True, True
    if s > w1.best_match:
        w1.best_match = s
        w1.best_word = w2
    if s > w2.best_match:
        w1.best_match = s
        w2.best_word = w1

    return l
shiny_leo.length = 1
shiny_leo.name = "shiny leo"
shiny_leo.baseline = None

# %%
aen_lions = aen_single_bab.scan(shiny_leo, gather=True)

# %%
# the scan function returns a triple, true_count, false_count, gathered_results
# nbshow is a utility method to colour and display a LineSet in Jupyter

utils.nbshow(aen_lions[2], book=True)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 1:12  </span>
#       <span>Vrbs</span>
#       <span>antiqua</span>
#       <span style="
#     background-color: #d2af79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">fuit</span>
#       <span>(Tyrii</span>
#       <span>tenuere</span>
#       <span style="
#     background-color: #d2af79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">coloni)</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 1:350 </span>
#       <span>Clam</span>
#       <span>ferro</span>
#       <span style="
#     background-color: #79bed2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">incautum</span>
#       <span>superat,</span>
#       <span>securus</span>
#       <span style="
#     background-color: #79bed2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">amorum</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 2:257 </span>
#       <span>Extulerat</span>
#       <span style="
#     background-color: #d27e79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">fatisque</span>
#       <span>deum</span>
#       <span>defensus</span>
#       <span style="
#     background-color: #d27e79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">iniquis</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 2:398 </span>
#       <span>Conserimus,</span>
#       <span style="
#     background-color: #7984d2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">multos</span>
#       <span>Danaum</span>
#       <span>demittimus</span>
#       <span style="
#     background-color: #7984d2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">Orco.</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:344 </span>
#       <span>Talia</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">fundebat</span>
#       <span>lacrimans</span>
#       <span>longosque</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">ciebat</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:6   </span>
#       <span>Postera</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">Phoebea</span>
#       <span>lustrabat</span>
#       <span>lampade</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">terras</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:10  </span>
#       <span>Quis</span>
#       <span>nouus</span>
#       <span>hic</span>
#       <span style="
#     background-color: #bbd279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">nostris</span>
#       <span>successit</span>
#       <span>sedibus</span>
#       <span style="
#     background-color: #bbd279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">hospes,</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:90  </span>
#       <span>Quam</span>
#       <span>simul</span>
#       <span>ac</span>
#       <span style="
#     background-color: #d28879;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">tali</span>
#       <span>persensit</span>
#       <span>peste</span>
#       <span style="
#     background-color: #d28879;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">teneri</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:137 </span>
#       <span>Sidoniam</span>
#       <span style="
#     background-color: #79b5d2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">picto</span>
#       <span>chlamydem</span>
#       <span>circumdata</span>
#       <span style="
#     background-color: #79b5d2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">limbo;</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:299 </span>
#       <span>Detulit</span>
#       <span style="
#     background-color: #d29279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">armari</span>
#       <span>classem</span>
#       <span>cursumque</span>
#       <span style="
#     background-color: #d29279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">parari.</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 5:485 </span>
#       <span>Protinus</span>
#       <span style="
#     background-color: #b1d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">Aeneas</span>
#       <span>celeri</span>
#       <span>certare</span>
#       <span style="
#     background-color: #b1d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">sagitta</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 5:549 </span>
#       <span>Agmen</span>
#       <span>habet</span>
#       <span style="
#     background-color: #79bed2

# %% [markdown]
# ## (Extra) Mosaics per Thousand - All Authors
#
# One or two stats for mosaics per thousand appear in the paper, for a few authors, but there is no full analysis (there wasn't space) so I may as well produce it here. Mosaic rhymes are discussed in Sec. 4.1.2.

# %%
full_works = [x for x in allbabs if not re.search('[0-9]', x.name)]

# %%
mpt = []
for w in full_works:
    r = locate_mosaics(w, thresh=5.5)
    x = len(r)/len(w.raw_source)*1000
    mpt.append({'work':w.name, 'mpt':x})
mpt_df = pd.DataFrame(mpt)

# %% [markdown]
# The results show the striking amount of additional rhyming ornamentation in the elegaic works. To a great extent this is supported by the increased propensity to leonine rhyme (if there are many leonine rhymes, it doesn't take many more to reach the threshold for a mosaic). Manually inspecting the results, however, also shows that line-initial rhymes come up quite often in the results, even though, as discussed above, they don't contribute to the mosaic score in this version of the code. Line initial rhyme is another feature which is more common in elegy vs epic.
#
# Note that, as I mention in the paper, even the modest number in the Aeneid (22 per thousand) is too great to have occurred by chance. It appears that this kind of ornamentation was used fairly sparingly (although Propertius' use could hardly be called sparing), but deliberately.

# %%
mpt_df.sort_values(by='mpt', ascending=False)
# Out:
#              work        mpt
# 9      Propertius  85.058618
# 1        Tibullus  79.774376
# 12          Fasti  67.578439
# 10       Heroides  63.006073
# 0         Tristia  61.155153
# 11            Ars  54.506438
# 15     Apotheosis  37.822878
# 16   Hamartigenia  37.267081
# 13    Argonautica  35.245459
# 8       Pharsalia  34.615385
# 5   Metamorphoses  34.141061
# 17   Psychomachia  33.916849
# 7         Thebaid  31.096059
# 6          Punica  24.426230
# 14            DRN  23.728814
# 3        Georgics  23.308958
# 2          Aeneid  21.849593
# 18      Hor. Sat.  16.564127
# 4       Juv. Sat.  16.554578

# %%
fasti_res = locate_mosaics(fast_bab, thresh=5.5)

# %%
for q, s in fasti_res[:7]:
    utils.nbshow(q, book=True)
    print('\n' + '-'*15 + "^ Score: %.2f ^" % s + '-'*15 + '\n')
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:161 </span>
#       <span>Ille</span>
#       <span>moras</span>
#       <span style="
#     background-color: #d2af79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">solis,</span>
#       <span>quibus</span>
#       <span>in</span>
#       <span>sua</span>
#       <span style="
#     background-color: #b1d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">signa</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">rediret,</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:162 </span>
#       <span style="padding-right: 1.5em"></span>
#       <span>Traditur</span>
#       <span style="
#     background-color: #d2af79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">exactis</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">disposuisse</span>
#       <span style="
#     background-color: #d2af79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">notis;</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:163 </span>
#       <span>Is</span>
#       <span>decies</span>
#       <span style="
#     background-color: #79abd2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">senos</span>
#       <span>ter</span>
#       <span>centum</span>
#       <span>et</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">quinque</span>
#       <span style="
#     background-color: #79abd2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">diebus</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:164 </span>
#       <span style="padding-right: 1.5em"></span>
#       <span>Iunxit</span>
#       <span>et</span>
#       <span>a</span>
#       <span style="
#     background-color: #79abd2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">pleno</span>
#       <span>tempora</span>
#       <span style="
#     background-color: #b1d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">quinta</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">die.</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 11.36 ^---------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:268 </span>
#       <span style="padding-right: 1.5em"></span>
#       <span>Et</span>
#       <span>posita</span>
#       <span>est</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">meritae</span>
#       <span>multa</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">tabella</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">deae.</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:269 </span>
#       <span>Saepe</span>
#       <span>potens</span>
#       <span style="
#     background-color: #d2af79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">uoti,</span>
#       <span>frontem</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">redimita</span>
#       <span style="
#     background-color: #d2af79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">coronis,</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:270 </span>
#       <span style="padding-right: 1.5em"></span>
#       <span>Femina</span>
#       <span style="
#     background-color: #d2cc79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">lucentes</span>
#       <span>portat</span>
#       <span>ab</span>
#       <span style="
#     background-color: #c5d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">Vrbe</span>
#       <span style="
#     background-color: #d2cc79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">faces.</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:271 </span>
#       <span>Regna</span>
#       <span>tenent</span>
#       <span style="
#     background-color: #d2af79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">fortes</span>
#       <span>manibus</span>
#       <span style="
#     background-color: #c5d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">pedibusque</span>
#       <span style="
#     background-color: #d2cc79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">fugaces,</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 10.03 ^---------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 2:784 </span>
#       <span style="padding-right: 1.5em"></span>
#       <span>Ense</span>
#       <span>latus</span>
#       <span style="
#     background-color: #d27e79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">cinxit</span>
#       <span>tergaque</span>
#       <span>pressit</span>
#       <span style="
#     background-color: #d27e79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">equi.</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 2:785 </span>
#       <span>Accipit</span>
#       <span style="
#     background-color: #81d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">aerata</span>
#       <span>iuuenem</span>
#       <span style="
#     background-color: #9ed279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">Collatia</span>
#       <span style="
#     background-color: #81d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">porta,</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 2:786 </span>
#       <span style="padding-right: 1.5em"></span>
#       <span>Condere</span>
#       <span>iam</span>
#       <span style="
#     background-color: #79c8d2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">uultus</span>
#       <span>sole</span>
#       <span>parante</span>
#       <span style="
#     background-color: #79c8d2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">suos.</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 2:787 </span>
#       <span>Hostis</span>
#       <span>ut</span>
#       <span>hospes</span>
#       <span style="
#     background-color: #d27e79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">init</span>
#       <span style="
#     background-color: #9ed279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">penetralia</span>
#       <span style="
#     background-color: #d27e79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">Collatini:</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 9.72 ^---------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:482 </span>
#       <span style="padding-right: 1.5em"></span>
#       <span>Frondibus,</span>
#       <span>in</span>
#       <span>lacrimas</span>
#       <span>cognite</span>
#       <span style="
#     background-color: #d2cc79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">Bacche</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">meas,</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:483 </span>
#       <span>Ausus</span>
#       <span>es</span>
#       <span>ante</span>
#       <span style="
#     background-color: #7984d2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">oculos</span>
#       <span>adducta</span>
#       <span>paelice</span>
#       <span style="
#     background-color: #7984d2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">nostros</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:484 </span>
#       <span style="padding-right: 1.5em"></span>
#       <span>Tam</span>
#       <span>bene</span>
#       <span style="
#     background-color: #79bed2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">compositum</span>
#       <span style="
#     background-color: #d2cc79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">sollicitare</span>
#       <span style="
#     background-color: #79bed2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">torum?</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 3:485 </span>
#       <span>Heu</span>
#       <span>ubi</span>
#       <span>pacta</span>
#       <span>fides?</span>
#       <span>ubi</span>
#       <span>quae</span>
#       <span style="
#     background-color: #d2cc79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">iurare</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">solebas?</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 9.58 ^---------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:276 </span>
#       <span style="padding-right: 1.5em"></span>
#       <span>Caelestum</span>
#       <span>Matrem</span>
#       <span>concaua</span>
#       <span style="
#     background-color: #d2af79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">puppis</span>
#       <span style="
#     background-color: #d29279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">habet.</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:277 </span>
#       <span>Illa</span>
#       <span>sui</span>
#       <span>per</span>
#       <span style="
#     background-color: #9ed279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">aquas</span>
#       <span>fertur</span>
#       <span style="
#     background-color: #b1d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">tutissima</span>
#       <span style="
#     background-color: #d29279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">nati,</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:278 </span>
#       <span style="padding-right: 1.5em"></span>
#       <span>Longaque</span>
#       <span>Phrixeae</span>
#       <span>stagna</span>
#       <span style="
#     background-color: #d2af79;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">sororis</span>
#       <span style="
#     background-color: #d29279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">adit,</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:279 </span>
#       <span>Rhoeteumque</span>
#       <span style="
#     background-color: #9ed279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">capax</span>
#       <span>Sigeaque</span>
#       <span style="
#     background-color: #b1d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">litora</span>
#       <span style="
#     background-color: #d29279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">transit,</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 9.42 ^---------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:331 </span>
#       <span>Nox</span>
#       <span>aderat:</span>
#       <span style="
#     background-color: #79abd2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">querno</span>
#       <span>religant</span>
#       <span>in</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">stipite</span>
#       <span style="
#     background-color: #c5d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">funem,</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:332 </span>
#       <span style="padding-right: 1.5em"></span>
#       <span>Dantque</span>
#       <span>leui</span>
#       <span style="
#     background-color: #79abd2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">somno</span>
#       <span>corpora</span>
#       <span>functa</span>
#       <span>cibo.</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:333 </span>
#       <span>Lux</span>
#       <span>aderat:</span>
#       <span style="
#     background-color: #79abd2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">querno</span>
#       <span>soluunt</span>
#       <span>a</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">stipite</span>
#       <span style="
#     background-color: #c5d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">funem,</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 4:334 </span>
#       <span style="padding-right: 1.5em"></span>
#       <span>Ante</span>
#       <span>tamen</span>
#       <span style="
#     background-color: #7984d2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">posito</span>
#       <span>tura</span>
#       <span style="
#     background-color: #d2b979;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">dedere</span>
#       <span style="
#     background-color: #7984d2;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">foco,</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 9.07 ^---------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Dominate</title>
#   </head>
#   <body>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 6:334 </span>
#       <span style="padding-right: 1.5em"></span>
#       <span>Captat,</span>
#       <span>et</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">errantes</span>
#       <span>fertque</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">refertque</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">pedes</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 6:335 </span>
#       <span>Aspicit</span>
#       <span>et</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">Vestam:</span>
#       <span>dubium</span>
#       <span>nymphamne</span>
#       <span>putarit</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 6:336 </span>
#       <span style="padding-right: 1.5em"></span>
#       <span>An</span>
#       <span>scierit</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">Vestam,</span>
#       <span>scisse</span>
#       <span>sed</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">ipse</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">negat.</span>
#     </p>
#     <p style="
#     line-height: 1.4;
#     margin-top: 0;
#     margin-bottom: 0;
#     font-family: Envy Code R;
#     font-size: medium&quot;
#     ">
#       <span style="float: left; width: 5em"> 6:337 </span>
#       <span>Spem</span>
#       <span>capit</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">obscenam,</span>
#       <span>furtimque</span>
#       <span style="
#     background-color: #d2c379;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">accedere</span>
#       <span style="
#     background-color: #a8d279;
#     padding-right: 0.25em;
#     padding-left: 0.25em;
#     padding-bottom: 0.08em;
#     color: black;
#     border-radius: 4px
#     ">temptat</span>
#     </p>
#   </body>
# </html>
# ---------------^ Score: 8.92 ^---------------
